# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def le(n):
    i=0
    f=0
    while(i<n):
        i= i+1
        f= f+1/((2*i-1)*(-1)**(i+1))
    return f

# %%
n=100
x=np.arange(0,100,2)
plt.plot(x,[le(i+1) for i in range(50)],label='Leibniz formula for π')
plt.plot(x,[np.pi/4 for i in range(50)],label='π/4')
plt.xlabel("n")
plt.ylim(0.65,1)
plt.legend()

# %% [markdown]
# ## logistic map

# %%
def lo(r,n):
    f=0.501
    i=0
    while(i<n):
        f=r*f*(1-f)
        i=i+1
    return f

# %%
lo(0.5,4)
# Out:
# F 1 = 0.125
# F 2 = 0.0546875
# F 3 = 0.025848388671875
# F 4 = 0.012590124737471342

# %%
#r=0.5, f0=0.5
n=100
x=np.arange(1,100,1)
plt.plot(x,[lo(0.5,i) for i in range(99)])
plt.xlabel("n")
plt.ylabel("fn",rotation=0)
# Out:
# Text(0, 0.5, 'fn')

# %%
#r=0.95 , f0=0.5
n=100
x=np.arange(1,100,1)
plt.plot(x,[lo(0.95,i) for i in range(99)])
plt.xlabel("n")
plt.ylabel("fn",rotation=0)
# Out:
# Text(0, 0.5, 'fn')

# %%
#r=2 , f0=0.5
n=100
x=np.arange(1,100,1)
plt.plot(x,[lo(2,i) for i in range(99)])
plt.xlabel("n")
plt.ylabel("fn",rotation=0)
# Out:
# Text(0, 0.5, 'fn')

# %%
#r=3.2, f0=0.5
n=100
x=np.arange(1,100,1)
plt.plot(x,[lo(3.2,i) for i in range(99)])
plt.xlabel("n")
plt.ylabel("fn",rotation=0)
# Out:
# Text(0, 0.5, 'fn')

# %%
#r=3.8 , f0=0.5
n=100
x=np.arange(1,100,1)
plt.plot(x,[lo(3.8,i) for i in range(99)])
plt.xlabel("n")
plt.ylabel("fn",rotation=0)
# Out:
# Text(0, 0.5, 'fn')

# %%
#r=3.8 , f0=0.501
n=100
x=np.arange(1,100,1)
plt.plot(x,[lo(3.8,i) for i in range(99)])
plt.xlabel("n")
plt.ylabel("fn",rotation=0)
# Out:
# Text(0, 0.5, 'fn')

# %% [markdown]
# ## sinc function

# %%
x=np.arange(0,100,1)
plt.plot(x,np.sin(x)/x)
# Out:
# <ipython-input-185-793a6d6e598e>:2: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x,np.sin(x)/x)

# %%
def s(x,n):
    i=0
    fac=1
    f=0
    while(i<n):
        r=i
        for k in range(1,2*r+2):
            fac =fac*k
        f=f+((-1)**i*x**(2*i))/fac 
        i=i+1
    return f

# %%
s(2,5)
# Out:
# 1.0
# -0.6666666666666666
# 0.022222222222222223
# -1.763668430335097e-05
# 1.9440789576004155e-10

# %%
x=np.arange(0,20,1)
plt.plot(x,s(x,5)) #n=5

# %%
x=np.arange(0,20,1)
plt.plot(x,s(x,10)) #n=10

# %%
x=np.arange(0,20,1)
plt.plot(x,s(x,20)) #n=20

# %%
x=np.arange(0,20,1)
plt.plot(x,s(x,50)) #n=50

# %%
x=np.arange(0,20,1)
plt.plot(x,s(x,100)) #n=100

# %%
x=np.arange(0,20,1)
plt.plot(x,s(x,200)) #n=200
